# %%
theboard = {'7': ' ', '8': ' ','9':' ',
            '4': ' ', '5':' ', '6':' ',
            '1': ' ', '2': ' ', '3': ' '}

# %%
def printboard(board):
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] +'|'+ board['5'] +'|'+ board['6'])
    print('-+-+-')
    print(board['1'] +'|'+ board['2'] +'|'+ board['3'])

# %%
def game():
    turn = 'X'
    count = 0
    for i in range (10):
        printboard(theboard)
        print("It is your turn " + turn + " which place you want to move?")
        move = input()
        
        if theboard[move] == ' ':
            theboard[move] = turn
            count += 1
        else:
            print("The place is already filled")
            continue
            
        if count >= 5:
            if theboard['7'] == theboard['8'] == theboard['9'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break
            elif theboard['4'] == theboard['5'] == theboard['6'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['1'] == theboard['2'] == theboard['3'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['7'] == theboard['4'] == theboard['1'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['8'] == theboard['5'] == theboard['2'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['6'] == theboard['3'] == theboard['9'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['7'] == theboard['5'] == theboard['3'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            elif theboard['5'] == theboard['1'] == theboard['9'] != ' ':
                printboard(theboard)
                print("*** " + turn +" Have won" + "***")
                print("Game Over")
                break    
            
        if count == 9:
            print("It is a tie")
            print("Game Over")
            break
        if turn == 'X':
            turn = 'O'
        else:
            turn = 'X'
    
    new_game = input("Do you want to play again?(Y/N)")
    if new_game == 'y' or new_game == 'Y':
        for key in keyboard_keys:
            theboard[key] = " "
        game()

# %%
game()
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# It is your turn X which place you want to move?
